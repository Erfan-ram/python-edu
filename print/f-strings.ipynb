# %% [markdown]
# the implantation of print a text in terminal could have done by f strings also

# %%
text = "text"

print(f"hello it is a {text}")
# Out:
# hello it is a text

# %% [markdown]
# #### Float formatting follows `"result: {value:{width}.{precision}}"`

# %%
names = {"john": 26.21456, "sam": 23.65, "erfan": 20.23, "sara": 17.36,
         "paul": 13.25, "cristiano": 42.23, "leo": 25.3541, "bernard": 23.23635}

for name, num in names.items():
    print(f"{name} is {num:{10}.{3}}")
# Out:
# john is       26.2
# sam is       23.6
# erfan is       20.2
# sara is       17.4
# paul is       13.2
# cristiano is       42.2
# leo is       25.4
# bernard is       23.2

# %% [markdown]
# By default, `.format()` aligns text to the left, numbers to the right. You can pass an optional `<`,`^`, or `>` to set a left, center or right alignment:

# %%
print('{0:=<8} | {1:-^8} | {2:.>8}'.format('Left','Center','Right'))
print('{0:=<8} | {1:-^8} | {2:.>8}'.format(11,22,33))
