# %% [markdown]
# the implantation of print a text in terminal could have done by f strings also

# %%
text = "text"

print(f"hello it is a {text}")
# Out:
# hello it is a text

# %%
names = ["john", "sam", "erfan", "sara", "paul", "cristiano", "leo", "bernard"]

for name in names:
    print(f"names in the list are {name:.{10}}")
