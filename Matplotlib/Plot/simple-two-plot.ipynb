# %%
import matplotlib.pyplot as plt

# %%
x = [num for num in range(20)]

# %%
y1 = list(map(lambda num: num, x))
y2 = list(map(lambda num: num ** 2, x))
y3 = [150 for numbers in x]

# %%
plt.plot(x, y1, c="red")
plt.plot(x, y2, c="blue")
plt.plot(x, y3, c="pink")

# %%
plt.xlabel('Number')
plt.ylabel('Duration (second)')
plt.title('Algorithms Comparison')
plt.show()
